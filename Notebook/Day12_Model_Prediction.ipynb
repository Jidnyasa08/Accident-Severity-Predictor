# %%
import pandas as pd
import joblib

# %%
loaded_model = joblib.load(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\model\accident_severity_model.pkl"
)

# %%
X = pd.read_csv(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Dataset\X_prepared.csv"
)

# %%
X.head()
# Out:
#    Time  Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0   420            1                   0              1                  0
# 1   420            1                   1              1                  4
# 2   420            1                   0              1                  4
# 3   594            3                   0              1                  4
# 4   594            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1               17
#
#    Owner_of_vehicle  Service_year_of_vehicle  ...  Number_of_casualties  \
# 0                 3                        3  ...                     2
# 1                 3                        2  ...                     2
# 2                 3                        6  ...                     2
# 3                 0                        6  ...                     2
# 4                 3                        2  ...                     2
#
#    Vehicle_movement  Casualty_class  Sex_of_casualty  Age_band_of_casualty  \
# 0                 2               3                2                     5
# 1                 2               3                2                     5
# 2                 2               0                1                     1
# 3                 2               2                0                     0
# 4                 2               3                2                     5
#
#    Casualty_severity  Work_of_casuality  Fitness_of_casuality  \
# 0                  3                  7                     5
# 1                  3                  7                     5
# 2                  2                  0                     5
# 3                  2                  0                     2
# 4                  3                  7                     5
#
#    Pedestrian_movement  Cause_of_accident
# 0                    5                  9
# 1                    5                 16
# 2                    5                  0
# 3                    5                  1
# 4                    5                 16
#
# [5 rows x 31 columns]

# %%
y_data = pd.read_csv(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Dataset\Y_prepared.csv"
)

# %%
y_data.head()
# Out:
#    Accident_severity
# 0                  2
# 1                  2
# 2                  1
# 3                  2
# 4                  2

# %%
y_data.columns
# Out:
# Index(['Accident_severity'], dtype='object')

# %%
y = y_data["Accident_severity"]

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# 4    2
# Name: Accident_severity, dtype: int64

# %%
severity_map = {
    0: "Slight",
    1: "Serious",
    2: "Fatal"
}

# %%
sample = X.iloc[[0]]

# %%
sample
# Out:
#    Time  Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0   420            1                   0              1                  0
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
#
#    Owner_of_vehicle  Service_year_of_vehicle  ...  Number_of_casualties  \
# 0                 3                        3  ...                     2
#
#    Vehicle_movement  Casualty_class  Sex_of_casualty  Age_band_of_casualty  \
# 0                 2               3                2                     5
#
#    Casualty_severity  Work_of_casuality  Fitness_of_casuality  \
# 0                  3                  7                     5
#
#    Pedestrian_movement  Cause_of_accident
# 0                    5                  9
#
# [1 rows x 31 columns]

# %%
prediction = loaded_model.predict(sample)

# %%
print("Encoded Prediction:", prediction)
# Out:
# Encoded Prediction: [2]

# %%
print(
    "Predicted Severity:",
    severity_map[prediction[0]]
)
# Out:
# Predicted Severity: Fatal

# %%
print(
    "Actual Severity:",
    severity_map[y.iloc[0]]
)
# Out:
# Actual Severity: Fatal

# %%
predictions = loaded_model.predict(
    X.iloc[:10]
)

# %%
print(predictions)
# Out:
# [2 2 1 2 2 2 2 2 2 2]

# %%
print(
    y.iloc[:10].values
)
# Out:
# [2 2 1 2 2 2 2 2 2 1]

# %%
comparison = pd.DataFrame({
    "Actual": [
        severity_map[value]
        for value in y.iloc[:10].values
    ],
    "Predicted": [
        severity_map[value]
        for value in predictions
    ]
})

comparison
# Out:
#     Actual Predicted
# 0    Fatal     Fatal
# 1    Fatal     Fatal
# 2  Serious   Serious
# 3    Fatal     Fatal
# 4    Fatal     Fatal
# 5    Fatal     Fatal
# 6    Fatal     Fatal
# 7    Fatal     Fatal
# 8    Fatal     Fatal
# 9  Serious     Fatal

# %%
comparison.to_csv(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Report\sample_predictions.csv",
    index=False
)
