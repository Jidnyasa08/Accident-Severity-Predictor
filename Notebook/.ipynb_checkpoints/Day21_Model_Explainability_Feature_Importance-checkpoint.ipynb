# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt

# %%
model = joblib.load(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Model\accident_severity_model.pkl"
)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
X = pd.read_csv(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Dataset\X_prepared.csv"
)

X.head()
# Out:
#    Time  Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0   420            1                   0              1                  0
# 1   420            1                   1              1                  4
# 2   420            1                   0              1                  4
# 3   594            3                   0              1                  4
# 4   594            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1               17
#
#    Owner_of_vehicle  Service_year_of_vehicle  ...  Number_of_casualties  \
# ...

# %%
feature_importance = model.feature_importances_

print(feature_importance)
# Out:
# [0.10777868 0.05211143 0.0378429  0.00930427 0.03267839 0.01971989
#  0.0461977  0.0548375  0.01642652 0.04453363 0.0183777  0.0487603
#  0.04021503 0.02308847 0.03945905 0.01369887 0.01574897 0.01714983
#  0.01841732 0.02898012 0.03801151 0.03267586 0.04002411 0.02092882
#  0.01951383 0.02886114 0.01390878 0.03347366 0.01281087 0.01255972
#  0.06190513]

# %%
importance_df = pd.DataFrame({
    "Feature": X.columns,
    "Importance": feature_importance
})

importance_df
# Out:
#                         Feature  Importance
# 0                          Time    0.107779
# 1                   Day_of_week    0.052111
# 2            Age_band_of_driver    0.037843
# 3                 Sex_of_driver    0.009304
# 4             Educational_level    0.032678
# 5       Vehicle_driver_relation    0.019720
# 6            Driving_experience    0.046198
# 7               Type_of_vehicle    0.054837
# 8              Owner_of_vehicle    0.016427
# 9       Service_year_of_vehicle    0.044534
# 10            Defect_of_vehicle    0.018378
# 11        Area_accident_occured    0.048760
# 12             Lanes_or_Medians    0.040215
# 13              Road_allignment    0.023088
# 14            Types_of_Junction    0.039459
# 15            Road_surface_type    0.013699
# 16      Road_surface_conditions    0.015749
# 17             Light_conditions    0.017150
# 18           Weather_conditions    0.018417
# 19            Type_of_collision    0.028980
# ...

# %%
importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df
# Out:
#                         Feature  Importance
# 0                          Time    0.107779
# 30            Cause_of_accident    0.061905
# 7               Type_of_vehicle    0.054837
# 1                   Day_of_week    0.052111
# 11        Area_accident_occured    0.048760
# 6            Driving_experience    0.046198
# 9       Service_year_of_vehicle    0.044534
# 12             Lanes_or_Medians    0.040215
# 22             Vehicle_movement    0.040024
# 14            Types_of_Junction    0.039459
# 20  Number_of_vehicles_involved    0.038012
# 2            Age_band_of_driver    0.037843
# 27            Work_of_casuality    0.033474
# 4             Educational_level    0.032678
# 21         Number_of_casualties    0.032676
# 19            Type_of_collision    0.028980
# 25         Age_band_of_casualty    0.028861
# 13              Road_allignment    0.023088
# 23               Casualty_class    0.020929
# 5       Vehicle_driver_relation    0.019720
# ...

# %%
top_10_features = importance_df.head(10)

top_10_features
# Out:
#                     Feature  Importance
# 0                      Time    0.107779
# 30        Cause_of_accident    0.061905
# 7           Type_of_vehicle    0.054837
# 1               Day_of_week    0.052111
# 11    Area_accident_occured    0.048760
# 6        Driving_experience    0.046198
# 9   Service_year_of_vehicle    0.044534
# 12         Lanes_or_Medians    0.040215
# 22         Vehicle_movement    0.040024
# 14        Types_of_Junction    0.039459

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    top_10_features["Feature"],
    top_10_features["Importance"]
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Influencing Accident Severity")

plt.gca().invert_yaxis()

plt.show()

# %%
importance_df.to_csv(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Report\feature_importance.csv",
    index=False
)

print("Feature importance saved successfully!")
# Out:
# Feature importance saved successfully!

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    top_10_features["Feature"],
    top_10_features["Importance"]
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Influencing Accident Severity")

plt.gca().invert_yaxis()

plt.savefig(
    r"C:\Users\jidny\OneDrive\Documents\Hiresnix_Internship\Project_1_Accident_Severity_Predictor\Report\feature_importance.png",
    bbox_inches="tight"
)

plt.show()
